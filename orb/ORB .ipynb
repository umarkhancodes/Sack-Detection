# %%
import cv2
from matplotlib import pyplot as plt 
import numpy as np

# %%
img1=cv2.imread("sack1.jpg",0)
#img1=cv2.resize(img1,(100,100))
img2=cv2.imread("Negative part b (67).jpg",0)
#img2=cv2.resize(img2,(100,100))

# %%
print(img1.shape)
print(img2.shape)
# Out:
# (1032, 774)
# (640, 352)

# %%
orb=cv2.ORB_create(nfeatures=20000)

# %%
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)

# %%
# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# Match descriptors.
matches = bf.match(des1,des2)

# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)
img3 = np.zeros((100,100))
# Draw first 10 matches.
img3=cv2.drawMatches(img1,kp1,img2,kp2,matches[:10],img3, flags=2)

plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f0abb7fb890>, None)

# %%
print(matches[:10])
# Out:
# [<DMatch 0x7f0ad3b8e510>, <DMatch 0x7f0ad3b8e650>, <DMatch 0x7f0ad3b8e2f0>, <DMatch 0x7f0ad3b90c90>, <DMatch 0x7f0ad3b90b10>, <DMatch 0x7f0ad3937f50>, <DMatch 0x7f0ad39372d0>, <DMatch 0x7f0ad3b8e230>, <DMatch 0x7f0ad3b32050>, <DMatch 0x7f0ad3b8f2d0>]
